# %% [markdown]
# <a href="https://colab.research.google.com/github/ErtanOz/PythonGIS/blob/main/Cologne_Street_Poly_JupyterProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install osmnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import osmnx as ox

# %%
admin = ox.geocode_to_gdf('Cologne')

# %%
admin_poly= admin.geometry.values[0]
admin_poly
# Out:
# <POLYGON ((6.773 51.062, 6.773 51.062, 6.773 51.062, 6.773 51.061, 6.773 51....>

# %%
G = ox.graph_from_polygon(admin_poly)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-df54a558f511> in <cell line: 1>()
# ----> 1 G = ox.graph_from_polygon(admin_poly)
#
# /usr/local/lib/python3.10/dist-packages/osmnx/graph.py in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     496         # create buffered graph from the downloaded data
#     497         bidirectional = network_type in settings.bidirectional_network_types
# --> 498         G_buff = _create_graph(response_jsons, retain_all=True, bidirectional=bidirectional)
#     499
#     500         # truncate buffered graph to the buffered polygon and retain_all for
#
# /usr/local/lib/python3.10/dist-packages/osmnx/graph.py in _create_graph(response_jsons, retain_all, bidirectional)
# ...

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (108766, 275805)

# %%
nodes, edges = ox.graph_to_gdfs(G)

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')

# %%
edges.plot(ax=ax, edgecolor = 'orange', linewidth = 0.3)
ax.axis('off')
# Out:
# (6.75352722, 7.181345380000001, 50.818032089999996, 51.097498310000006)

# %%
f, ax=plt.subplots(1,1,figsize=(10,10))
edges.plot(ax=ax, edgecolor = 'orange', linewidth = 0.3)
ax.axis('off')
# Out:
# (6.75352722, 7.181345380000001, 50.818032089999996, 51.097498310000006)
